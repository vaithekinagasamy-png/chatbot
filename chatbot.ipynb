# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "id": "Uw2hpkKFazBq"
      },
      "outputs": [],
      "source": [
        "print(\"Bot: Welcome! Type 'bye' to exit.\")\n",
        "\n",
        "responses = {\n",
        "    \"hello\": \"Hi! How can I help you?\",\n",
        "    \"how are you\": \"I am doing well.\",\n",
        "    \"what is your name\": \"I am a Rule-Based Chatbot.\",\n",
        "    \"python\": \"Python is a popular programming language.\",\n",
        "    \"java\": \"Java is an object-oriented programming language.\"\n",
        "}\n",
        "\n",
        "while True:\n",
        "\n",
        "    user = input(\"You: \").lower()\n",
        "\n",
        "    if user == \"bye\":\n",
        "        print(\"Bot: Goodbye!\")\n",
        "        break\n",
        "\n",
        "    elif user in responses:\n",
        "        print(\"Bot:\", responses[user])\n",
        "\n",
        "    else:\n",
        "        print(\"Bot: Sorry, I don't understand that question.\")"
      ]
    }
  ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_485/1722439367.py in <cell line: 0>()
#      17     {
#      18       "cell_type": "code",
# ---> 19       "execution_count": null,
#      20       "metadata": {
#      21         "id": "Uw2hpkKFazBq"
#
# NameError: name 'null' is not defined
